# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

import csv
import requests
import re

url = "https://en.wikipedia.org/wiki/Glossary_of_biology"
page = requests.get(url)

soup = BeautifulSoup(page.text, "html.parser")
#k=soup.find("div",{"id" : "bodyContent"})
info = soup.find_all("div", {'id':'bodyContent'})
comp_info = pd.DataFrame()
cleaned_id_text = []
for i in info[0].find_all('dt'):
    cleaned_id_text.append(i.text)
cleaned_id__attrb_text = []
for i in info[0].find_all('dd'):
    cleaned_id__attrb_text.append(i.text)

comp_info['Id'] = cleaned_id_text
comp_info
my_df=pd.DataFrame([comp_info])
#my_df=pd.DataFrame(k,keywords[k])

pd.DataFrame([comp_info['Id']]).T.reset_index().to_csv('Biology.csv', header=True)

comp_info
# Out:
#                                Id
# 0               abiotic component
# 1                      abscission
# 2                      absorption
# 3             absorption spectrum
# 4                 acclimatization
# 5                      acetyl-CoA
# 6                      acoelomate
# 7                action potential
# 8               activation energy
# 9                     active site
# 10               active transport
# 11                     adaptation
# 12             adaptive radiation
# 13                        adenine
# 14   adenosine triphosphate (ATP)
# 15                 adipose tissue
# 16                        aerobic
# 17                    aerobiology
# 18                    agriculture
# 19                    agrobiology
# 20                           alga
# 21          allopatric speciation
# 22                     amino acid
# 23                        amniote
# 24                      anaerobic
# 25           analogous structures
# ...
