# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

import csv
import requests
import re

url = "https://en.wikipedia.org/wiki/Glossary_of_chemistry_terms"
page = requests.get(url)

soup = BeautifulSoup(page.text, "html.parser")
#k=soup.find("div",{"id" : "bodyContent"})
info = soup.find_all("div", {'id':'bodyContent'})
comp_info = pd.DataFrame()
cleaned_id_text = []
for i in info[0].find_all('dt'):
    cleaned_id_text.append(i.text)
cleaned_id__attrb_text = []
for i in info[0].find_all('dd'):
    cleaned_id__attrb_text.append(i.text)

comp_info['Id'] = cleaned_id_text
comp_info
my_df=pd.DataFrame([comp_info])
#my_df=pd.DataFrame(k,keywords[k])

pd.DataFrame([comp_info['Id']]).T.reset_index().to_csv('Chemistry.csv', header=True)

comp_info
# Out:
#                                    Id
# 0                       absolute zero
# 1                          absorbance
# 2                          absorption
# 3                           abundance
# 4                            accuracy
# 5                                acid
# 6                      acid anhydride
# 7     acid dissociation constant (Ka)
# 8                           actinides
# 9                   activated complex
# 10                  activation energy
# 11                    activity series
# 12                       actual yield
# 13                            acyclic
# 14                  addition reaction
# 15                           adhesion
# 16                         adsorption
# 17                           aeration
# 18                            alcohol
# 19                           aldehyde
# 20                       alkali metal
# 21               alkaline earth metal
# 22                             alkane
# 23                             alkene
# 24                        alkyl group
# 25                             alkyne
# 26                            allomer
# 27                          allotrope
# 28                              alloy
# 29                            amalgam
# ..                                ...
# 454                  valence electron
# 455               valence bond theory
# 456                           valency
# 457               van der Waals force
# 458                van 't Hoff factor
# 459                             vapor
# 460                    vapor pressure
# 461                      vaporization
# 462                         viscosity
# 463                        volatility
# 464                          volt (V)
# 465                         voltmeter
# 466                            volume
# 467               volumetric analysis
# 468                  volumetric flask
# 469                       watch glass
# 470                             water
# 471                     wave function
# 472                         weak acid
# 473                         weak base
# 474                     wet chemistry
# 475                              work
# 476                           work-up
# 477                             X-ray
# 478                 X-ray diffraction
# 479  X-ray photoelectron spectroscopy
# 480                             yield
# 481                      zone melting
# 482                        zwitterion
# 483                              zinc
#
# [484 rows x 1 columns]
